# %% [markdown]
# # `lxml.etree` 2
#
# Demonstrating just a few more things, such as going verse line by verse line or paragraph by paragraph, and keeping nonnormalized forms in your token dict. This notebook will use one of the student transcriptions, not included in the repository, so substitute in your own TEI XML file with matching metadata.

# %%
from lxml import etree

# %%
parser = etree.XMLParser(remove_blank_text=True,resolve_entities=True)
filename = '../projects/example.xml'
tree = etree.parse(filename, parser=parser)
root = tree.getroot()

# %%
# Create a dict with characters we want replaced:
substitutions = {
    'ę': 'æ',
    'ƿ': 'w',
    'ẏ': 'y',
    'ſ': 's',
    '': 's', # Using the glyph for descending s, instead of the unicode key point
    'v': 'u',
    'j': 'i',
    '⁊': 'and',
    ' ': '',
    '\n': ''
}

# Write a function carrying out the desired operations:
def normalize(token):
    # Lowercase:
    token = token.lower()
    for k,v in substitutions.items():
        # Carry out replacements:
        token = token.replace(k, v)
    return token

# %% [markdown]
# We're going to assume our document organizes word tokens into either verse lines or paragraphs, or both. Also, let's provide for any rubrics (`<head>` nodes) encountered and treat them as equivalent to our paragraph/verse line units; if that's undesirable, you can always remove `head` from the iterator or set up your code to flag which chunks are rubrics.
#
# Another thing we neglected to do last week is retain the form as encountered alongside the normalized token form. We'll do this simply by adding an additional key to our dictionary, and normalizing the form for just one of the two.

# %%
# Our outermost container will be a list of lists in this approach:
data = []
text = root.find('.//{http://www.tei-c.org/ns/1.0}text')


# And now we compile a list of token dictionaries for each rubric, verse line, or paragraph:
for chunk in text.iter('{http://www.tei-c.org/ns/1.0}head', '{http://www.tei-c.org/ns/1.0}p', '{http://www.tei-c.org/ns/1.0}l'):
    this_data = []
    for i in chunk.iter('{http://www.tei-c.org/ns/1.0}w'):
        dictionary = dict()
        dictionary['form'] = etree.tostring(i, method='text', encoding='unicode')
        dictionary['norm'] = normalize(dictionary['form'])
        dictionary['pos'] = i.get('pos')
        dictionary['lemma'] = i.get('lemma')
        this_data.append(dictionary)
    data.append(this_data)

# %%
data
# Out:
# [[{'form': ' Ælfric', 'norm': 'ælfric', 'pos': 'NR^N', 'lemma': ''},
#   {'form': 'gret', 'norm': 'gret', 'pos': 'VBPI', 'lemma': 'gretan'},
#   {'form': 'eadmolice',
#    'norm': 'eadmolice',
#    'pos': 'ADV',
#    'lemma': 'eadmolice'},
#   {'form': 'ÆĐelƿerd', 'norm': 'æđelwerd', 'pos': 'NR^A', 'lemma': ''},
#   {'form': 'Ealdorman',
#    'norm': 'ealdorman',
#    'pos': 'N^A',
#    'lemma': 'ealdorman'}],
#  [{'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'ic', 'norm': 'ic', 'pos': 'PRO^N', 'lemma': 'ic'},
#   {'form': 'secge', 'norm': 'secge', 'pos': 'VBPI', 'lemma': 'secgan'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'PRO^D', 'lemma': 'þu'},
#   {'form': 'leof', 'norm': 'leof', 'pos': 'ADJ^N', 'lemma': 'leof'},
#   {'form': '\uf149Þæt', 'norm': '\uf149þæt', 'pos': 'C', 'lemma': 'Þæt'},
#   {'form': 'ic', 'norm': 'ic', 'pos': 'PRO^N', 'lemma': 'ic'},
#   {'form': 'hæbbe', 'norm': 'hæbbe', 'pos': 'HVPI', 'lemma': 'habban'},
#   {'form': 'nu', 'norm': 'nu', 'pos': 'ADV', 'lemma': 'nu'},
#   {'form': 'gegaderod', 'norm': 'gegaderod', 'pos': 'VBN', 'lemma': 'gadrian'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'þẏssere', 'norm': 'þyssere', 'pos': 'D^D', 'lemma': 'þes'},
#   {'form': 'bec', 'norm': 'bec', 'pos': 'N^D', 'lemma': 'boc'},
#   {'form': 'þaera', 'norm': 'þaera', 'pos': 'D^G', 'lemma': 'se'},
#   {'form': 'halgena', 'norm': 'halgena', 'pos': 'N^G', 'lemma': 'halga'},
#   {'form': 'þroƿunga', 'norm': 'þrowunga', 'pos': 'N ^A', 'lemma': 'þrowung'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'me', 'norm': 'me', 'pos': 'PRO^D', 'lemma': 'ic'},
#   {'form': 'to', 'norm': 'to', 'pos': 'P', 'lemma': 'to'},
#   {'form': 'onhagode', 'norm': 'onhagode', 'pos': 'VBPI', 'lemma': 'onhagian'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'englisc', 'norm': 'englisc', 'pos': 'ADJ^D', 'lemma': 'englisc'},
#   {'form': 'to', 'norm': 'to', 'pos': 'TO', 'lemma': 'to'},
#   {'form': 'aƿendene', 'norm': 'awendene', 'pos': 'VB^D', 'lemma': 'awendan'},
#   {'form': 'forþan', 'norm': 'forþan', 'pos': 'ADV', 'lemma': 'forþan'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'ðu', 'norm': 'ðu', 'pos': 'PRO^N', 'lemma': 'þu'},
#   {'form': 'leȯf', 'norm': 'leȯf', 'pos': 'ADJ^N', 'lemma': 'leof'},
#   {'form': 'sƿiðost', 'norm': 'swiðost', 'pos': 'ADV', 'lemma': 'swiðost'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'æðelmær', 'norm': 'æðelmær', 'pos': 'NR^N', 'lemma': None},
#   {'form': 'sƿẏlcera', 'norm': 'swylcera', 'pos': 'ADJ^G', 'lemma': 'swylc'},
#   {'form': 'geƿrita', 'norm': 'gewrita', 'pos': 'N^G', 'lemma': 'gewrit'},
#   {'form': 'me', 'norm': 'me', 'pos': 'PRO^D', 'lemma': 'ic'},
#   {'form': 'bædon', 'norm': 'bædon', 'pos': 'VBDI', 'lemma': 'biddan'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'of', 'norm': 'of', 'pos': 'P', 'lemma': 'of'},
#   {'form': 'handum', 'norm': 'handum', 'pos': 'N^D', 'lemma': 'hand'},
#   {'form': 'gelæhton', 'norm': 'gelæhton', 'pos': 'VBDI', 'lemma': 'gelæcan'},
#   {'form': 'eoƿerne', 'norm': 'eowerne', 'pos': 'D^A', 'lemma': 'eower'},
#   {'form': 'geleafan', 'norm': 'geleafan', 'pos': 'N^A', 'lemma': 'geleafa'},
#   {'form': 'to', 'norm': 'to', 'pos': 'TO', 'lemma': 'to'},
#   {'form': 'getrẏmmenne',
#    'norm': 'getrymmenne',
#    'pos': 'VB^D',
#    'lemma': 'getrymman'},
#   {'form': 'mid', 'norm': 'mid', 'pos': 'P', 'lemma': 'mid'},
#   {'form': 'þære', 'norm': 'þære', 'pos': 'D^D', 'lemma': 'se'},
#   {'form': 'gerecednẏsse',
#    'norm': 'gerecednysse',
#    'pos': 'N^D',
#    'lemma': 'gerecednes'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'ge', 'norm': 'ge', 'pos': 'PRO^N', 'lemma': 'ge'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'eoƿrum', 'norm': 'eowrum', 'pos': 'D^D', 'lemma': 'eower'},
#   {'form': 'gereorde', 'norm': 'gereorde', 'pos': 'N^D', 'lemma': 'gereord'},
#   {'form': 'næfdon', 'norm': 'næfdon', 'pos': 'VBDI', 'lemma': 'habban'},
#   {'form': 'ær', 'norm': 'ær', 'pos': 'ADV', 'lemma': 'ær'},
#   {'form': 'Þu', 'norm': 'þu', 'pos': 'PRO^N', 'lemma': 'þu'},
#   {'form': 'ƿast', 'norm': 'wast', 'pos': 'VBPI', 'lemma': 'witan'},
#   {'form': 'leof', 'norm': 'leof', 'pos': 'ADJ^N', 'lemma': 'leof'},
#   {'form': '\uf149Þæt', 'norm': '\uf149þæt', 'pos': 'C', 'lemma': 'Þæt'},
#   {'form': 'ƿe', 'norm': 'we', 'pos': 'PRO^N', 'lemma': None},
#   {'form': 'aƿendon', 'norm': 'awendon', 'pos': 'VBDI', 'lemma': None},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': None},
#   {'form': 'þam', 'norm': 'þam', 'pos': 'D^D', 'lemma': None},
#   {'form': 'tƿam', 'norm': 'twam', 'pos': 'Q^D', 'lemma': 'twegen'},
#   {'form': 'ærrum', 'norm': 'ærrum', 'pos': 'ADJ^D', 'lemma': 'ær'},
#   {'form': 'bocum', 'norm': 'bocum', 'pos': 'N^D', 'lemma': 'boc'},
#   {'form': 'þæra', 'norm': 'þæra', 'pos': 'D^G', 'lemma': 'se'},
#   {'form': 'halgena', 'norm': 'halgena', 'pos': 'N^G', 'lemma': 'halga'},
#   {'form': 'þroƿunga', 'norm': 'þrowunga', 'pos': 'N^A', 'lemma': 'þrowung'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'lif', 'norm': 'lif', 'pos': 'N^A', 'lemma': 'lif'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'angelcẏnn',
#    'norm': 'angelcynn',
#    'pos': 'N^N',
#    'lemma': 'angelcynn'},
#   {'form': 'mid', 'norm': 'mid', 'pos': 'P', 'lemma': 'mid'},
#   {'form': 'freols', 'norm': 'freols', 'pos': 'N^D', 'lemma': 'freols'},
#   {'form': 'dagum', 'norm': 'dagum', 'pos': 'N^D', 'lemma': 'dæg'},
#   {'form': 'wurþað', 'norm': 'wurþað', 'pos': 'VBPI', 'lemma': 'weorþian'},
#   {'form': 'nu', 'norm': 'nu', 'pos': 'ADV', 'lemma': 'nu'},
#   {'form': 'geƿearð', 'norm': 'gewearð', 'pos': 'VBDI', 'lemma': 'weorþan'},
#   {'form': 'us', 'norm': 'us', 'pos': 'PRO^D', 'lemma': 'we'},
#   {'form': '\uf149Þæt', 'norm': '\uf149þæt', 'pos': 'C', 'lemma': 'Þæt'},
#   {'form': 'ƿe', 'norm': 'we', 'pos': 'PRO^N', 'lemma': 'we'},
#   {'form': 'þas', 'norm': 'þas', 'pos': 'D^A', 'lemma': 'þes'},
#   {'form': 'boc', 'norm': 'boc', 'pos': 'N^A', 'lemma': 'boc'},
#   {'form': 'be ', 'norm': 'be', 'pos': 'P', 'lemma': 'be'},
#   {'form': 'þæra', 'norm': 'þæra', 'pos': 'D^G', 'lemma': 'se'},
#   {'form': 'halgena', 'norm': 'halgena', 'pos': 'N^G', 'lemma': 'halga'},
#   {'form': 'ðroƿungum', 'norm': 'ðrowungum', 'pos': 'N^D', 'lemma': 'þrowung'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'life', 'norm': 'life', 'pos': 'N^D', 'lemma': 'lif'},
#   {'form': 'gedihton', 'norm': 'gedihton', 'pos': 'VBDI', 'lemma': 'gedihtan'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'mẏnster', 'norm': 'mynster', 'pos': 'N^N', 'lemma': 'mynster'},
#   {'form': 'menn', 'norm': 'menn', 'pos': 'N^N', 'lemma': 'mann'},
#   {'form': 'mid', 'norm': 'mid', 'pos': 'P', 'lemma': 'mid'},
#   {'form': 'heora', 'norm': 'heora', 'pos': 'PRO^G', 'lemma': 'he'},
#   {'form': 'þenungum', 'norm': 'þenungum', 'pos': 'N^D', 'lemma': 'þenung'},
#   {'form': 'betƿux', 'norm': 'betwux', 'pos': 'ADV', 'lemma': 'betwux'},
#   {'form': 'him', 'norm': 'him', 'pos': 'PRO^D', 'lemma': 'he'},
#   {'form': 'ƿurðiað', 'norm': 'wurðiað', 'pos': 'VBPI', 'lemma': 'weorþian'}],
#  [{'form': ' Ne ', 'norm': 'ne', 'pos': 'NEG', 'lemma': 'ne'},
#   {'form': 'secge', 'norm': 'secge', 'pos': 'VBPI', 'lemma': 'secgan'},
#   {'form': 'ƿe', 'norm': 'we', 'pos': 'PRO^N', 'lemma': 'we'},
#   {'form': 'nan', 'norm': 'nan', 'pos': 'D^A', 'lemma': 'nan'},
#   {'form': 'þincg', 'norm': 'þincg', 'pos': 'N^A', 'lemma': 'þing'},
#   {'form': 'niƿes', 'norm': 'niwes', 'pos': 'ADJ^G', 'lemma': 'niwe'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'þissere', 'norm': 'þissere', 'pos': 'D^D', 'lemma': 'þes'},
#   {'form': 'gesetnẏsse',
#    'norm': 'gesetnysse',
#    'pos': 'N^D',
#    'lemma': 'gesetnes'}],
#  [{'form': 'forþan', 'norm': 'forþan', 'pos': 'ADV', 'lemma': 'forþan'},
#   {'form': 'ðe', 'norm': 'ðe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'hit', 'norm': 'hit', 'pos': 'PRO^N', 'lemma': 'hit'},
#   {'form': 'stod', 'norm': 'stod', 'pos': 'VBDI', 'lemma': 'standan'},
#   {'form': 'gefẏrn', 'norm': 'gefyrn', 'pos': 'ADV', 'lemma': 'gefyrn'},
#   {'form': 'aƿriten', 'norm': 'awriten', 'pos': 'VBN', 'lemma': 'awritan'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'Ledenbocum',
#    'norm': 'ledenbocum',
#    'pos': 'N^D',
#    'lemma': 'ledenboc'}],
#  [{'form': 'þeah', 'norm': 'þeah', 'pos': 'CONJ', 'lemma': 'þeah'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'þa', 'norm': 'þa', 'pos': 'D^N', 'lemma': 'se'},
#   {'form': 'læƿedan', 'norm': 'læwedan', 'pos': 'ADJ^N', 'lemma': 'læwede'},
#   {'form': 'men', 'norm': 'men', 'pos': 'N^N', 'lemma': 'mann'},
#   {'form': '\uf149Þæt', 'norm': '\uf149þæt', 'pos': 'PRO^A', 'lemma': 'Þæt'},
#   {'form': 'nẏston', 'norm': 'nyston', 'pos': 'VBDI', 'lemma': 'nytan'}],
#  [{'form': 'Nelle', 'norm': 'nelle', 'pos': 'MDPI neg', 'lemma': 'nyllan'},
#   {'form': 'ƿe', 'norm': 'we', 'pos': 'PRO^N', 'lemma': 'we'},
#   {'form': 'eac', 'norm': 'eac', 'pos': 'ADV', 'lemma': 'eac'},
#   {'form': 'mid', 'norm': 'mid', 'pos': 'P', 'lemma': 'mid'},
#   {'form': 'leasungum', 'norm': 'leasungum', 'pos': 'N^D', 'lemma': 'leasung'},
#   {'form': 'þẏllic', 'norm': 'þyllic', 'pos': 'ADJ^A', 'lemma': 'þyllic'},
#   {'form': 'liccetan', 'norm': 'liccetan', 'pos': 'VB', 'lemma': 'licettan'}],
#  [{'form': 'forþan', 'norm': 'forþan', 'pos': 'ADV', 'lemma': 'forþan'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'geleaffulle',
#    'norm': 'geleaffulle',
#    'pos': 'ADJ^N',
#    'lemma': 'geleaffull'},
#   {'form': 'fæderas', 'norm': 'fæderas', 'pos': 'N^N', 'lemma': 'fæder'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'halige', 'norm': 'halige', 'pos': 'ADJ^N', 'lemma': 'halig'},
#   {'form': 'lareoƿas', 'norm': 'lareowas', 'pos': 'N^N', 'lemma': 'lareow'}],
#  [{'form': 'hit', 'norm': 'hit', 'pos': 'PRO^A', 'lemma': 'hit'},
#   {'form': 'aƿriton', 'norm': 'awriton', 'pos': 'VBDI', 'lemma': 'awritan'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'ledenspræce',
#    'norm': 'ledenspræce',
#    'pos': 'N^D',
#    'lemma': 'leden-sprǣc'},
#   {'form': 'to', 'norm': 'to', 'pos': 'P', 'lemma': 'to'},
#   {'form': 'langum', 'norm': 'langum', 'pos': 'ADJ^D', 'lemma': 'lang'},
#   {'form': 'gemẏnde', 'norm': 'gemynde', 'pos': 'N^D', 'lemma': 'gemynd'}],
#  [{'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'to', 'norm': 'to', 'pos': 'P', 'lemma': 'to'},
#   {'form': 'trẏmmincge',
#    'norm': 'trymmincge',
#    'pos': 'N^D',
#    'lemma': 'trymming'},
#   {'form': 'þam', 'norm': 'þam', 'pos': 'D^D', 'lemma': 'se'},
#   {'form': 'toƿerdum', 'norm': 'towerdum', 'pos': 'ADJ^D', 'lemma': 'toweard'},
#   {'form': 'mannum', 'norm': 'mannum', 'pos': 'N^D', 'lemma': 'mann'}],
#  [{'form': 'Sum', 'norm': 'sum', 'pos': 'ADJ^N', 'lemma': 'sum'},
#   {'form': 'ƿitega', 'norm': 'witega', 'pos': 'N^N', 'lemma': 'witega'},
#   {'form': 'clẏpode', 'norm': 'clypode', 'pos': 'VBDI', 'lemma': 'clypian'},
#   {'form': 'þurh', 'norm': 'þurh', 'pos': 'P', 'lemma': 'þurh'},
#   {'form': 'þone', 'norm': 'þone', 'pos': 'D^A', 'lemma': 'se'},
#   {'form': 'halgan', 'norm': 'halgan', 'pos': 'ADJ^A', 'lemma': 'halig'},
#   {'form': 'gast', 'norm': 'gast', 'pos': 'N^A', 'lemma': 'gast'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'cƿæð', 'norm': 'cwæð', 'pos': 'VBDI', 'lemma': 'cweðan'},
#   {'form': 'Mirabilis', 'norm': 'mirabilis', 'pos': 'FW', 'lemma': None},
#   {'form': 'deus', 'norm': 'deus', 'pos': 'FW', 'lemma': None},
#   {'form': 'in', 'norm': 'in', 'pos': 'FW', 'lemma': None},
#   {'form': 'sanctis', 'norm': 'sanctis', 'pos': 'FW', 'lemma': None},
#   {'form': 'suis', 'norm': 'suis', 'pos': 'FW', 'lemma': None},
#   {'form': 'et', 'norm': 'et', 'pos': 'FW', 'lemma': None},
#   {'form': 'cetera', 'norm': 'cetera', 'pos': 'FW', 'lemma': None},
#   {'form': 'Ƿundorlic',
#    'norm': 'wundorlic',
#    'pos': 'ADJ^N',
#    'lemma': 'wundorlic'},
#   {'form': 'is', 'norm': 'is', 'pos': 'VBPI', 'lemma': 'beon'},
#   {'form': 'god', 'norm': 'god', 'pos': 'N^N', 'lemma': 'god'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'his', 'norm': 'his', 'pos': 'PRO^D', 'lemma': 'his'},
#   {'form': 'halgum', 'norm': 'halgum', 'pos': 'ADJ^D', 'lemma': 'halig'},
#   {'form': 'he', 'norm': 'he', 'pos': 'PRO^N', 'lemma': 'he'},
#   {'form': 'sẏlf', 'norm': 'sylf', 'pos': 'ADJ^N', 'lemma': 'self'},
#   {'form': 'forgifð', 'norm': 'forgifð', 'pos': 'VBPI', 'lemma': 'forgiefan'},
#   {'form': 'mihte', 'norm': 'mihte', 'pos': 'N^A', 'lemma': 'miht'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'strengðe', 'norm': 'strengðe', 'pos': 'N^A', 'lemma': 'strengþu'},
#   {'form': 'his', 'norm': 'his', 'pos': 'PRO^D', 'lemma': 'his'},
#   {'form': 'folce', 'norm': 'folce', 'pos': 'N^D', 'lemma': 'folc'},
#   {'form': 'gebletsod',
#    'norm': 'gebletsod',
#    'pos': 'VBN',
#    'lemma': 'gebletsian'},
#   {'form': 'is', 'norm': 'is', 'pos': 'VBPI', 'lemma': 'beon'},
#   {'form': 'he', 'norm': 'he', 'pos': 'PRO^N', 'lemma': 'he'},
#   {'form': 'god', 'norm': 'god', 'pos': 'N^N', 'lemma': 'god'},
#   {'form': 'Ƿe', 'norm': 'we', 'pos': 'PRO^N', 'lemma': 'we'},
#   {'form': 'aƿritað', 'norm': 'awritað', 'pos': 'VBPI', 'lemma': 'awritan'},
#   {'form': 'fela', 'norm': 'fela', 'pos': 'Q', 'lemma': 'fela'},
#   {'form': 'ƿundra', 'norm': 'wundra', 'pos': 'N^G', 'lemma': 'wundor'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'þissere', 'norm': 'þissere', 'pos': 'D^D', 'lemma': 'þes'},
#   {'form': 'bec', 'norm': 'bec', 'pos': 'N^D', 'lemma': 'boc'},
#   {'form': 'forþan', 'norm': 'forþan', 'pos': 'CONJ', 'lemma': 'forþan'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'god', 'norm': 'god', 'pos': 'N^N', 'lemma': 'god'},
#   {'form': 'is ', 'norm': 'is', 'pos': 'VBPI', 'lemma': 'beon'},
#   {'form': 'ƿundorlic',
#    'norm': 'wundorlic',
#    'pos': 'ADJ^N',
#    'lemma': 'wundorlic'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'his', 'norm': 'his', 'pos': 'PRO^D', 'lemma': 'his'},
#   {'form': 'halgum', 'norm': 'halgum', 'pos': 'ADJ^D', 'lemma': 'halig'},
#   {'form': 'sƿa', 'norm': 'swa', 'pos': 'ADV', 'lemma': 'swa'},
#   {'form': 'sƿa', 'norm': 'swa', 'pos': 'ADV', 'lemma': 'swa'},
#   {'form': 'we', 'norm': 'we', 'pos': 'PRO^N', 'lemma': 'we'},
#   {'form': 'ær', 'norm': 'ær', 'pos': 'ADV', 'lemma': 'ær'},
#   {'form': 'sædon', 'norm': 'sædon', 'pos': 'VBDI', 'lemma': 'secgan'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'hir', 'norm': 'hir', 'pos': 'PRO^GEN', 'lemma': 'hie'},
#   {'form': 'halgena', 'norm': 'halgena', 'pos': 'ADJ^G', 'lemma': 'halga'},
#   {'form': 'ƿundra', 'norm': 'wundra', 'pos': 'N^A', 'lemma': 'wundor'},
#   {'form': 'ƿurðiað', 'norm': 'wurðiað', 'pos': 'VBPI', 'lemma': 'weorþian'},
#   {'form': 'hine ·\n        ', 'norm': 'hine·', 'pos': 'PRO^A', 'lemma': 'he'},
#   {'form': 'forþan ', 'norm': 'forþan', 'pos': 'CONJ', 'lemma': 'forþan'},
#   {'form': 'þe ', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'he ', 'norm': 'he', 'pos': 'PRO^N', 'lemma': 'he'},
#   {'form': 'ƿorhte ', 'norm': 'worhte', 'pos': 'VBDI', 'lemma': 'wyrcan'},
#   {'form': 'þa \n        ', 'norm': 'þa', 'pos': 'D^A', 'lemma': 'se'},
#   {'form': 'ƿundra ', 'norm': 'wundra', 'pos': 'N^A', 'lemma': 'wundor'},
#   {'form': 'þurh ', 'norm': 'þurh', 'pos': 'P', 'lemma': 'þurh'},
#   {'form': 'hi ', 'norm': 'hi', 'pos': 'PRO^A', 'lemma': 'hie'}],
#  [{'form': 'An', 'norm': 'an', 'pos': 'ADJ^N', 'lemma': 'an'},
#   {'form': 'ƿoruld', 'norm': 'woruld', 'pos': 'N^N', 'lemma': 'woruld'},
#   {'form': 'cẏnincg', 'norm': 'cynincg', 'pos': 'N^N', 'lemma': 'cyning'},
#   {'form': 'hæfð', 'norm': 'hæfð', 'pos': 'VBPI', 'lemma': 'habban'},
#   {'form': 'fela', 'norm': 'fela', 'pos': 'Q', 'lemma': 'fela'},
#   {'form': 'þegna', 'norm': 'þegna', 'pos': 'N^G', 'lemma': 'þegn'}],
#  [{'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'mislice', 'norm': 'mislice', 'pos': 'ADJ^A', 'lemma': 'mislic'},
#   {'form': 'ƿicneras', 'norm': 'wicneras', 'pos': 'N^A', 'lemma': 'wicnere'},
#   {'form': 'he', 'norm': 'he', 'pos': 'PRO^N', 'lemma': 'he'},
#   {'form': 'ne', 'norm': 'ne', 'pos': 'NEG', 'lemma': 'ne'},
#   {'form': 'mæg', 'norm': 'mæg', 'pos': 'VBDK', 'lemma': 'magan'},
#   {'form': 'beon', 'norm': 'beon', 'pos': 'VAI', 'lemma': 'beon'},
#   {'form': 'ƿurðful', 'norm': 'wurðful', 'pos': 'ADJ^N', 'lemma': 'weorðfull'},
#   {'form': 'cẏnincg', 'norm': 'cynincg', 'pos': 'N^N', 'lemma': 'cyning'}],
#  [{'form': 'buton', 'norm': 'buton', 'pos': 'CONJ', 'lemma': 'butan'},
#   {'form': 'he', 'norm': 'he', 'pos': 'PRO^N', 'lemma': 'he'},
#   {'form': 'hæbbe', 'norm': 'hæbbe', 'pos': 'VBSI', 'lemma': 'habban'},
#   {'form': 'þa', 'norm': 'þa', 'pos': 'D^A', 'lemma': 'se'},
#   {'form': 'geþincðe', 'norm': 'geþincðe', 'pos': 'N^A', 'lemma': 'geþingþu'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'REL', 'lemma': 'þe'},
#   {'form': 'him', 'norm': 'him', 'pos': 'PRO^D', 'lemma': 'he'},
#   {'form': 'gebẏriað',
#    'norm': 'gebyriað',
#    'pos': 'VBPI',
#    'lemma': 'gebeorian'}],
#  [{'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'sƿẏlce', 'norm': 'swylce', 'pos': 'ADV', 'lemma': 'swylc'},
#   {'form': 'þening', 'norm': 'þening', 'pos': 'N^A', 'lemma': 'þenung'},
#   {'form': 'men', 'norm': 'men', 'pos': 'N^A', 'lemma': 'mann'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'þeaƿfæstnẏsse',
#    'norm': 'þeawfæstnysse',
#    'pos': 'N^A',
#    'lemma': 'þeawfæstnes'},
#   {'form': 'him', 'norm': 'him', 'pos': 'PRO^D', 'lemma': 'he'},
#   {'form': 'gebeodon', 'norm': 'gebeodon', 'pos': 'VBDI', 'lemma': 'beodan'}],
#  [{'form': 'Sƿa', 'norm': 'swa', 'pos': 'ADV', 'lemma': 'swa'},
#   {'form': 'is', 'norm': 'is', 'pos': 'VBPI', 'lemma': 'beon'},
#   {'form': 'eac', 'norm': 'eac', 'pos': 'ADV', 'lemma': 'eac'},
#   {'form': 'þam', 'norm': 'þam', 'pos': 'D^D', 'lemma': 'se'},
#   {'form': 'ælmihtigan',
#    'norm': 'ælmihtigan',
#    'pos': 'ADJ^D',
#    'lemma': 'ælmihtig'},
#   {'form': 'gode', 'norm': 'gode', 'pos': 'N^D', 'lemma': 'god'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'ealle', 'norm': 'ealle', 'pos': 'ADJ^A', 'lemma': 'eall'},
#   {'form': 'þincg', 'norm': 'þincg', 'pos': 'N^A', 'lemma': 'þing'},
#   {'form': 'gesceop', 'norm': 'gesceop', 'pos': 'VBPI', 'lemma': 'scieppan'}],
#  [{'form': 'him', 'norm': 'him', 'pos': 'PRO^D', 'lemma': 'he'},
#   {'form': 'gerisð', 'norm': 'gerisð', 'pos': 'VBPI', 'lemma': 'gerisan'},
#   {'form': '\uf149Þæt', 'norm': '\uf149þæt', 'pos': 'C', 'lemma': 'Þæt'},
#   {'form': 'he', 'norm': 'he', 'pos': 'PRO^N', 'lemma': 'he'},
#   {'form': 'hæbbe', 'norm': 'hæbbe', 'pos': 'VBSI', 'lemma': 'habban'},
#   {'form': 'halige', 'norm': 'halige', 'pos': 'ADJ^A', 'lemma': 'halig'},
#   {'form': 'þenas', 'norm': 'þenas', 'pos': 'N^A', 'lemma': 'þegn'}],
#  [{'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'his', 'norm': 'his', 'pos': 'PRO^GEN', 'lemma': 'his'},
#   {'form': 'ƿillan', 'norm': 'willan', 'pos': 'N^A', 'lemma': 'willa'},
#   {'form': 'gefẏllað', 'norm': 'gefyllað', 'pos': 'VBPI', 'lemma': 'gefyllan'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'þæra', 'norm': 'þæra', 'pos': 'D^G', 'lemma': 'se'},
#   {'form': 'is', 'norm': 'is', 'pos': 'VBPI', 'lemma': 'beon'},
#   {'form': 'fela', 'norm': 'fela', 'pos': 'Q', 'lemma': 'fela'}],
#  [{'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'mannum', 'norm': 'mannum', 'pos': 'N^D', 'lemma': 'mann'},
#   {'form': 'anum', 'norm': 'anum', 'pos': 'ADJ^D', 'lemma': 'an'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'he', 'norm': 'he', 'pos': 'PRO^N', 'lemma': 'he'},
#   {'form': 'of', 'norm': 'of', 'pos': 'P', 'lemma': 'of'},
#   {'form': 'middan', 'norm': 'middan', 'pos': 'ADJ^D', 'lemma': 'middel'},
#   {'form': 'earde', 'norm': 'earde', 'pos': 'N^D', 'lemma': 'eard'},
#   {'form': 'geceas', 'norm': 'geceas', 'pos': 'VBDI', 'lemma': 'ceosan'}],
#  [{'form': '\uf149Þæt', 'norm': '\uf149þæt', 'pos': 'C', 'lemma': 'Þæt'},
#   {'form': ' nan', 'norm': 'nan', 'pos': 'Q', 'lemma': 'nan'},
#   {'form': 'bocere', 'norm': 'bocere', 'pos': 'N^N', 'lemma': 'bocere'},
#   {'form': 'ne', 'norm': 'ne', 'pos': 'NEG', 'lemma': 'ne'},
#   {'form': 'mag', 'norm': 'mag', 'pos': 'VBP', 'lemma': 'magan'},
#   {'form': 'þeah', 'norm': 'þeah', 'pos': 'ADV', 'lemma': 'þeah'},
#   {'form': 'he', 'norm': 'he', 'pos': 'PRO^N', 'lemma': 'he'},
#   {'form': 'mẏcel', 'norm': 'mycel', 'pos': 'ADJ^A', 'lemma': 'micel'},
#   {'form': 'cunne', 'norm': 'cunne', 'pos': 'VBP', 'lemma': 'cunnan'}],
#  [{'form': 'heora', 'norm': 'heora', 'pos': 'PRO$^G', 'lemma': 'he'},
#   {'form': 'naman', 'norm': 'naman', 'pos': 'N^A', 'lemma': 'nama'},
#   {'form': 'aƿriten', 'norm': 'awriten', 'pos': 'VBN', 'lemma': 'awritan'},
#   {'form': 'forþan', 'norm': 'forþan', 'pos': 'P', 'lemma': 'forþan'},
#   {'form': 'þe', 'norm': 'þe', 'pos': 'C', 'lemma': 'þe'},
#   {'form': 'hi', 'norm': 'hi', 'pos': 'PRO^N', 'lemma': 'hie'},
#   {'form': 'nat', 'norm': 'nat', 'pos': 'VBP', 'lemma': 'nytan'},
#   {'form': 'nan', 'norm': 'nan', 'pos': 'nan', 'lemma': None},
#   {'form': 'man', 'norm': 'man', 'pos': None, 'lemma': 'mann'}],
#  [{'form': 'hi', 'norm': 'hi', 'pos': 'PRO^N', 'lemma': 'hie'},
#   {'form': 'sẏnd', 'norm': 'synd', 'pos': 'VBP', 'lemma': 'beon'},
#   {'form': 'ungerẏme', 'norm': 'ungeryme', 'pos': 'ADJ^N', 'lemma': 'ungerim'},
#   {'form': 'sƿa', 'norm': 'swa', 'pos': 'ADV', 'lemma': 'swa'},
#   {'form': 'sƿa', 'norm': 'swa', 'pos': 'ADV', 'lemma': 'swa'},
#   {'form': 'hit', 'norm': 'hit', 'pos': 'PRO^N', 'lemma': 'hit'},
#   {'form': 'gerisð', 'norm': 'gerisð', 'pos': 'VBP', 'lemma': 'gerisan'},
#   {'form': 'gode', 'norm': 'gode', 'pos': 'N^D', 'lemma': 'god'}],
#  [{'form': 'ac', 'norm': 'ac', 'pos': 'CONJ', 'lemma': 'ac'},
#   {'form': 'ƿe', 'norm': 'we', 'pos': 'PRO^N', 'lemma': 'we'},
#   {'form': 'ƿoldon', 'norm': 'woldon', 'pos': 'VBD', 'lemma': 'willan'},
#   {'form': 'gesettan', 'norm': 'gesettan', 'pos': 'VB', 'lemma': 'gesettan'},
#   {'form': 'be', 'norm': 'be', 'pos': 'P', 'lemma': 'be'},
#   {'form': 'sumum', 'norm': 'sumum', 'pos': 'Q^D', 'lemma': 'sum'},
#   {'form': 'þas', 'norm': 'þas', 'pos': 'D^A', 'lemma': 'þes'},
#   {'form': 'boc', 'norm': 'boc', 'pos': 'N^A', 'lemma': 'boc'}],
#  [{'form': 'mannum', 'norm': 'mannum', 'pos': 'N^D', 'lemma': 'mann'},
#   {'form': 'to', 'norm': 'to', 'pos': 'P', 'lemma': 'to'},
#   {'form': 'getrẏmminge',
#    'norm': 'getrymminge',
#    'pos': 'N^D',
#    'lemma': 'getrymming'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'to', 'norm': 'to', 'pos': 'P', 'lemma': 'to'},
#   {'form': 'munde', 'norm': 'munde', 'pos': 'N^D', 'lemma': 'mynd'},
#   {'form': 'us', 'norm': 'us', 'pos': 'PRO^D', 'lemma': 'we'},
#   {'form': 'sẏlfum', 'norm': 'sylfum', 'pos': 'ADJ^D', 'lemma': 'self'}],
#  [{'form': '\uf149Þæt', 'norm': '\uf149þæt', 'pos': 'C', 'lemma': 'Þæt'},
#   {'form': 'hi', 'norm': 'hi', 'pos': 'PRO^N', 'lemma': 'hie'},
#   {'form': 'us', 'norm': 'us', 'pos': 'PRO^D', 'lemma': 'we'},
#   {'form': 'þingion', 'norm': 'þingion', 'pos': 'VBP', 'lemma': 'þingian'},
#   {'form': 'to', 'norm': 'to', 'pos': 'P', 'lemma': 'to'},
#   {'form': 'þam', 'norm': 'þam', 'pos': 'D^D', 'lemma': 'se'},
#   {'form': 'ælmihtigan',
#    'norm': 'ælmihtigan',
#    'pos': 'ADJ^D',
#    'lemma': 'ælmihtig'},
#   {'form': 'gode ·\n      ', 'norm': 'gode·', 'pos': 'N^D', 'lemma': 'god'}],
#  [{'form': 'sƿa', 'norm': 'swa', 'pos': 'ADV', 'lemma': 'swa'},
#   {'form': 'sƿa', 'norm': 'swa', 'pos': 'ADV', 'lemma': 'swa'},
#   {'form': 'ƿe', 'norm': 'we', 'pos': 'PRO^N', 'lemma': 'we'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'ƿorulde', 'norm': 'worulde', 'pos': 'N^D', 'lemma': 'woruld'},
#   {'form': 'heora', 'norm': 'heora', 'pos': 'PRO$^G', 'lemma': 'he'},
#   {'form': 'ƿundra', 'norm': 'wundra', 'pos': 'N^G', 'lemma': 'wundor'},
#   {'form': 'cẏðað', 'norm': 'cyðað', 'pos': 'VBP', 'lemma': 'cyþan'}],
#  [{'form': 'Ic', 'norm': 'ic', 'pos': 'PRO^N', 'lemma': 'ic'},
#   {'form': 'bidde', 'norm': 'bidde', 'pos': 'VBP', 'lemma': 'biddan'},
#   {'form': 'nu', 'norm': 'nu', 'pos': 'ADV', 'lemma': 'nu'},
#   {'form': 'on', 'norm': 'on', 'pos': 'P', 'lemma': 'on'},
#   {'form': 'godes', 'norm': 'godes', 'pos': 'N^G', 'lemma': 'god'},
#   {'form': 'naman', 'norm': 'naman', 'pos': 'N^A', 'lemma': 'nama'},
#   {'form': 'gif', 'norm': 'gif', 'pos': 'C', 'lemma': 'gif'},
#   {'form': 'hƿa', 'norm': 'hwa', 'pos': 'PRO^N', 'lemma': 'hwa'},
#   {'form': 'þas', 'norm': 'þas', 'pos': 'D^A', 'lemma': 'þes'},
#   {'form': 'boc', 'norm': 'boc', 'pos': 'N^A', 'lemma': 'boc'},
#   {'form': 'aƿritan', 'norm': 'awritan', 'pos': 'VB', 'lemma': 'awritan'},
#   {'form': 'ƿille', 'norm': 'wille', 'pos': 'VBP', 'lemma': 'willan'},
#   {'form': '\uf149Þæt', 'norm': '\uf149þæt', 'pos': 'C', 'lemma': 'Þæt'},
#   {'form': 'he', 'norm': 'he', 'pos': 'PRO^N', 'lemma': 'he'},
#   {'form': 'hi', 'norm': 'hi', 'pos': 'PRO^A', 'lemma': 'hie'},
#   {'form': 'ƿel', 'norm': 'wel', 'pos': 'ADV', 'lemma': 'wel'},
#   {'form': 'gerihte', 'norm': 'gerihte', 'pos': 'VB', 'lemma': 'gerihtan'},
#   {'form': 'be', 'norm': 'be', 'pos': 'P', 'lemma': 'be'},
#   {'form': 'þære', 'norm': 'þære', 'pos': 'D^D', 'lemma': 'se'},
#   {'form': 'bẏsne', 'norm': 'bysne', 'pos': 'N^D', 'lemma': 'bysen'},
#   {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#   {'form': 'þær', 'norm': 'þær', 'pos': 'ADV', 'lemma': 'þær'},
#   {'form': 'na ', 'norm': 'na', 'pos': 'NEG', 'lemma': 'na'},
#   {'form': 'mare', 'norm': 'mare', 'pos': 'QR^A', 'lemma': 'mara'},
#   {'form': 'betƿux', 'norm': 'betwux', 'pos': 'P', 'lemma': 'betwux'},
#   {'form': 'ne', 'norm': 'ne', 'pos': 'NEG', 'lemma': 'ne'},
#   {'form': 'sette', 'norm': 'sette', 'pos': 'VBD', 'lemma': 'sette'},
#   {'form': 'þonne', 'norm': 'þonne', 'pos': 'P', 'lemma': 'þonne'},
#   {'form': 'ƿe', 'norm': 'we', 'pos': 'PRO^N', 'lemma': 'we'},
#   {'form': 'aƿendon', 'norm': 'awendon', 'pos': 'VBD', 'lemma': 'awendan '},
#   {'form': 'vale', 'norm': 'uale', 'pos': 'FW', 'lemma': None},
#   {'form': 'in', 'norm': 'in', 'pos': 'FW', 'lemma': None},
#   {'form': 'dhodomino', 'norm': 'dhodomino', 'pos': 'FW', 'lemma': None}]]

# %% [markdown]
# This approach still omits any non-word content, such as punctuation marks. You can of course modify the approach to cover any content you need.
#
# If we now want to perform operations on all tokens, we simply merge our lower-level lists of token dictionaries back into one master list. This is where list comprehension gets a little hard to read, so we'll call our constituent lists `inner` and `outer` respectively to help understand the syntax:

# %%
all_tokens = [inner for outer in data for inner in outer]
len(all_tokens)
#alternative_way = []
#for i in data:
#    alternative_way.extend(i)
# Out:
# 378

# %%
all_tokens[:10]
#alternative_way[:10]
# Out:
# [{'form': ' Ælfric', 'norm': 'ælfric', 'pos': 'NR^N', 'lemma': ''},
#  {'form': 'gret', 'norm': 'gret', 'pos': 'VBPI', 'lemma': 'gretan'},
#  {'form': 'eadmolice',
#   'norm': 'eadmolice',
#   'pos': 'ADV',
#   'lemma': 'eadmolice'},
#  {'form': 'ÆĐelƿerd', 'norm': 'æđelwerd', 'pos': 'NR^A', 'lemma': ''},
#  {'form': 'Ealdorman',
#   'norm': 'ealdorman',
#   'pos': 'N^A',
#   'lemma': 'ealdorman'},
#  {'form': '⁊', 'norm': 'and', 'pos': 'CONJ', 'lemma': 'and'},
#  {'form': 'ic', 'norm': 'ic', 'pos': 'PRO^N', 'lemma': 'ic'},
#  {'form': 'secge', 'norm': 'secge', 'pos': 'VBPI', 'lemma': 'secgan'},
#  {'form': 'þe', 'norm': 'þe', 'pos': 'PRO^D', 'lemma': 'þu'},
#  {'form': 'leof', 'norm': 'leof', 'pos': 'ADJ^N', 'lemma': 'leof'}]

# %%
with open('test.txt', 'w') as outfile: 
    for chunk in data:
        text = ' '.join([token['norm'] for token in chunk])
        outfile.write(text + '\n')
